# %% [markdown]
# # Librerías

# %%
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None

# %%
Enero2020 = pd.read_csv('sample_data/Data/Enero2020.csv',sep=",")
Enero2021 = pd.read_csv('sample_data/Data/Enero2021.csv',sep="|")
Septiembre2019 = pd.read_csv('sample_data/Data/Septiembre2019.csv',sep="|")
Septiembre2020 = pd.read_csv('sample_data/Data/Septiembre2020.csv',sep="|")

# %%
CompleteDataset = pd.concat([Enero2020,Enero2021,Septiembre2019,Septiembre2020])

# %%
print(CompleteDataset.head())
# Out:
#    OBJECTID  TID                  INICIO                     FIN     AÑO  \
# 0   8472321    1  2020/01/02 08:30:00+00  2020/01/02 08:45:00+00  2020.0
# 1   8472322    1  2020/01/02 08:45:00+00  2020/01/02 09:00:00+00  2020.0
# 2   8472323    1  2020/01/02 09:00:00+00  2020/01/02 09:15:00+00  2020.0
# 3   8472324    1  2020/01/02 09:15:00+00  2020/01/02 09:30:00+00  2020.0
# 4   8472325    1  2020/01/02 10:45:00+00  2020/01/02 11:00:00+00  2020.0
#
#    HORA  DISTANCE  TYPE  VEL_PROMEDIO CUARTO_HORA DIA_SEMANA        MES  \
# 0   8.0     17482     0     28.893699    08:30:00     Jueves  January
# 1   8.0     17482     0     28.435784    08:45:00     Jueves  January
# 2   9.0     17482     0     28.958299    09:00:00     Jueves  January
# 3   9.0     17482     0     28.542233    09:15:00     Jueves  January
# 4  10.0     17482     0     27.197580    10:45:00     Jueves  January
#
#   NAME_FROM     NAME_TO  VEL_PONDERADA          CODIGO COEF_BRT COEF_MIXTO  \
# ...

# %%
CompleteDataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9251093 entries, 0 to 2142964
# Data columns (total 23 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   OBJECTID             int64
#  1   TID                  int64
#  2   INICIO               object
#  3   FIN                  object
#  4   AÑO                  float64
#  5   HORA                 float64
#  6   DISTANCE             int64
#  7   TYPE                 int64
#  8   VEL_PROMEDIO         float64
#  9   CUARTO_HORA          object
#  10  DIA_SEMANA           object
#  11  MES                  object
#  12  NAME_FROM            object
#  13  NAME_TO              object
#  14  VEL_PONDERADA        float64
#  15  CODIGO               object
#  16  COEF_BRT             object
#  17  COEF_MIXTO           object
#  18  VEL_MEDIA_BRT        object
#  19  VEL_MEDIA_MIXTO      object
#  20  VEL_MEDIA_PONDERADA  object
#  21  CONTROL              float64
#  22  SHAPE.LEN            float64
# ...

# %%
correlation = CompleteDataset.corr()

# %%
import seaborn as sns
sns.heatmap(correlation)
